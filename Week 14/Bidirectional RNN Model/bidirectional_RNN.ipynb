# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
# Load dataset
data = pd.read_csv('/content/AirQualityUCI.csv', sep=';', decimal=',')

# %%
# Drop columns with non-numeric data (like date/time) and last two columns with null values
data = data.select_dtypes(include=[np.number])
data = data.iloc[:, :-2]  # Remove the last two columns which contain null values

# %%
# Drop rows with NaN values
data = data.dropna()

# %%
# Selecting the relevant features and target (adjust as needed)
features = data.iloc[:, :-1]
target = data.iloc[:, -1]

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Standardize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Reshape data for RNN input
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
# Convert data to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32)

# %%
# Create a custom dataset class
class AirQualityDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
# Create DataLoaders
train_dataset = AirQualityDataset(X_train_tensor, y_train_tensor)
test_dataset = AirQualityDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# Define the Bidirectional RNN model
class BiRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, pooling):
        super(BiRNN, self).__init__()
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True, bidirectional=True)
        self.pooling = pooling
        self.fc = nn.Linear(hidden_size * 2, output_size)  # Multiply by 2 for bidirectionality

    def forward(self, x):
        out, _ = self.rnn(x)
        if self.pooling == 'max':
            out, _ = torch.max(out, dim=1)
        elif self.pooling == 'avg':
            out = torch.mean(out, dim=1)
        out = self.fc(out)
        return out

# %%
# Training and evaluation function
def train_and_evaluate(hidden_size=64, pooling='avg', epochs=50, optimizer_name='Adam'):
    input_size = X_train_tensor.shape[2]
    output_size = 1  # Assuming a regression task
    model = BiRNN(input_size, hidden_size, output_size, pooling)

    # Define loss function and optimizer
    criterion = nn.MSELoss()
    if optimizer_name == 'SGD':
        optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
    elif optimizer_name == 'RMSProp':
        optimizer = torch.optim.RMSprop(model.parameters(), lr=0.01)
    elif optimizer_name == 'Adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

    # Learning rate scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.5, verbose=True)

    # Early stopping
    best_loss = float('inf')
    patience = 10
    counter = 0

    results = []

    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs.squeeze(), y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * X_batch.size(0)
        train_loss /= len(train_loader.dataset)

        # Evaluate on test data
        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for X_batch, y_batch in test_loader:
                outputs = model(X_batch)
                loss = criterion(outputs.squeeze(), y_batch)
                test_loss += loss.item() * X_batch.size(0)
        test_loss /= len(test_loader.dataset)

        scheduler.step(test_loss)

        results.append((epoch + 1, train_loss, test_loss))

        if test_loss < best_loss:
            best_loss = test_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print("Early stopping triggered")
                break

    return results

# %%
# Store and display results
all_results = {}

# %%
# Experiment with different hidden sizes
hidden_sizes = [32, 64, 128]
for hidden_size in hidden_sizes:
    print(f"\nExperiment with Hidden Size: {hidden_size}")
    all_results[f"Hidden Size {hidden_size}"] = train_and_evaluate(hidden_size=hidden_size)
# Out:
# Experiment with Hidden Size: 32
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Experiment with Hidden Size: 64
#
# Experiment with Hidden Size: 128

# %%
# Experiment with different pooling methods
pooling_methods = ['max', 'avg']
for pooling in pooling_methods:
    print(f"\nExperiment with Pooling Method: {pooling}")
    all_results[f"Pooling {pooling}"] = train_and_evaluate(pooling=pooling)
# Out:
# Experiment with Pooling Method: max
#
# Experiment with Pooling Method: avg

# %%
# Experiment with different epochs
epochs_list = [5, 50, 100, 250, 350]
for epochs in epochs_list:
    print(f"\nExperiment with Epochs: {epochs}")
    all_results[f"Epochs {epochs}"] = train_and_evaluate(epochs=epochs)
# Out:
# Experiment with Epochs: 5
#
# Experiment with Epochs: 50
#
# Experiment with Epochs: 100
#
# Experiment with Epochs: 250
# Early stopping triggered
#
# Experiment with Epochs: 350
# Early stopping triggered

# %%
# Experiment with different optimizers
optimizers = ['SGD', 'RMSProp', 'Adam']
for optimizer_name in optimizers:
    print(f"\nExperiment with Optimizer: {optimizer_name}")
    all_results[f"Optimizer {optimizer_name}"] = train_and_evaluate(optimizer_name=optimizer_name)
# Out:
# Experiment with Optimizer: SGD
#
# Experiment with Optimizer: RMSProp
# Early stopping triggered
#
# Experiment with Optimizer: Adam

# %%
# Display all results
for key, result in all_results.items():
    print(f"\nResults for {key}")
    for epoch, train_loss, test_loss in result:
        print(f"Epoch {epoch}: Train Loss = {train_loss:.4f}, Test Loss = {test_loss:.4f}")
# Out:
# Results for Hidden Size 32
# Epoch 1: Train Loss = 863.3726, Test Loss = 354.9443
# Epoch 2: Train Loss = 165.3560, Test Loss = 47.8526
# Epoch 3: Train Loss = 18.4349, Test Loss = 3.5783
# Epoch 4: Train Loss = 1.3611, Test Loss = 0.5251
# Epoch 5: Train Loss = 0.4617, Test Loss = 0.0984
# Epoch 6: Train Loss = 0.1341, Test Loss = 0.1811
# Epoch 7: Train Loss = 0.1170, Test Loss = 0.0793
# Epoch 8: Train Loss = 0.0998, Test Loss = 0.1389
# Epoch 9: Train Loss = 0.1630, Test Loss = 0.1161
# Epoch 10: Train Loss = 0.1205, Test Loss = 0.1926
# Epoch 11: Train Loss = 0.2877, Test Loss = 0.1789
# Epoch 12: Train Loss = 0.1360, Test Loss = 0.0720
# Epoch 13: Train Loss = 0.0785, Test Loss = 0.0930
# Epoch 14: Train Loss = 0.0603, Test Loss = 0.0910
# Epoch 15: Train Loss = 0.1092, Test Loss = 0.1031
# Epoch 16: Train Loss = 0.1450, Test Loss = 0.4995
# Epoch 17: Train Loss = 0.2076, Test Loss = 0.0942
# Epoch 18: Train Loss = 0.0968, Test Loss = 0.1277
# Epoch 19: Train Loss = 0.0281, Test Loss = 0.0307
# Epoch 20: Train Loss = 0.0189, Test Loss = 0.0318
# Epoch 21: Train Loss = 0.0296, Test Loss = 0.0448
# Epoch 22: Train Loss = 0.0253, Test Loss = 0.0308
# Epoch 23: Train Loss = 0.0303, Test Loss = 0.0299
# Epoch 24: Train Loss = 0.0353, Test Loss = 0.0316
# Epoch 25: Train Loss = 0.0226, Test Loss = 0.0358
# Epoch 26: Train Loss = 0.0436, Test Loss = 0.2291
# Epoch 27: Train Loss = 0.1346, Test Loss = 0.0524
# Epoch 28: Train Loss = 0.0286, Test Loss = 0.0266
# Epoch 29: Train Loss = 0.0287, Test Loss = 0.0268
# Epoch 30: Train Loss = 0.0418, Test Loss = 0.0303
# Epoch 31: Train Loss = 0.0446, Test Loss = 0.0302
# Epoch 32: Train Loss = 0.0422, Test Loss = 0.0260
# Epoch 33: Train Loss = 0.0411, Test Loss = 0.0336
# Epoch 34: Train Loss = 0.0707, Test Loss = 0.0578
# Epoch 35: Train Loss = 0.0456, Test Loss = 0.0350
# Epoch 36: Train Loss = 0.0294, Test Loss = 0.0399
# Epoch 37: Train Loss = 0.0935, Test Loss = 0.0489
# Epoch 38: Train Loss = 0.0256, Test Loss = 0.0795
# Epoch 39: Train Loss = 0.0125, Test Loss = 0.0172
# Epoch 40: Train Loss = 0.0121, Test Loss = 0.0173
# Epoch 41: Train Loss = 0.0118, Test Loss = 0.0141
# Epoch 42: Train Loss = 0.0117, Test Loss = 0.0233
# Epoch 43: Train Loss = 0.0150, Test Loss = 0.0140
# Epoch 44: Train Loss = 0.0134, Test Loss = 0.0229
# Epoch 45: Train Loss = 0.0138, Test Loss = 0.0244
# Epoch 46: Train Loss = 0.0151, Test Loss = 0.0176
# Epoch 47: Train Loss = 0.0172, Test Loss = 0.0372
# Epoch 48: Train Loss = 0.0187, Test Loss = 0.0133
# Epoch 49: Train Loss = 0.0189, Test Loss = 0.0250
# Epoch 50: Train Loss = 0.0146, Test Loss = 0.0367
#
# Results for Hidden Size 64
# Epoch 1: Train Loss = 549.6629, Test Loss = 59.7028
# Epoch 2: Train Loss = 14.0381, Test Loss = 0.9825
# Epoch 3: Train Loss = 0.4960, Test Loss = 0.2134
# Epoch 4: Train Loss = 0.2131, Test Loss = 0.1877
# Epoch 5: Train Loss = 0.2069, Test Loss = 0.3655
# Epoch 6: Train Loss = 0.2343, Test Loss = 0.0672
# Epoch 7: Train Loss = 0.1518, Test Loss = 0.0579
# Epoch 8: Train Loss = 0.1844, Test Loss = 0.0755
# Epoch 9: Train Loss = 0.0864, Test Loss = 0.1070
# Epoch 10: Train Loss = 0.4178, Test Loss = 0.0995
# Epoch 11: Train Loss = 0.1503, Test Loss = 0.0967
# Epoch 12: Train Loss = 0.1364, Test Loss = 0.0926
# Epoch 13: Train Loss = 0.0959, Test Loss = 0.1131
# Epoch 14: Train Loss = 0.0361, Test Loss = 0.0306
# Epoch 15: Train Loss = 0.0240, Test Loss = 0.0240
# Epoch 16: Train Loss = 0.0264, Test Loss = 0.0273
# Epoch 17: Train Loss = 0.0361, Test Loss = 0.0379
# Epoch 18: Train Loss = 0.0456, Test Loss = 0.0450
# Epoch 19: Train Loss = 0.0607, Test Loss = 0.0566
# Epoch 20: Train Loss = 0.0438, Test Loss = 0.0403
# Epoch 21: Train Loss = 0.0778, Test Loss = 0.1978
# Epoch 22: Train Loss = 0.0230, Test Loss = 0.0113
# Epoch 23: Train Loss = 0.0199, Test Loss = 0.0131
# Epoch 24: Train Loss = 0.0163, Test Loss = 0.0198
# Epoch 25: Train Loss = 0.0154, Test Loss = 0.0153
# Epoch 26: Train Loss = 0.0253, Test Loss = 0.0369
# Epoch 27: Train Loss = 0.0257, Test Loss = 0.0178
# Epoch 28: Train Loss = 0.0159, Test Loss = 0.0134
# Epoch 29: Train Loss = 0.0099, Test Loss = 0.0110
# Epoch 30: Train Loss = 0.0098, Test Loss = 0.0109
# Epoch 31: Train Loss = 0.0098, Test Loss = 0.0113
# Epoch 32: Train Loss = 0.0109, Test Loss = 0.0094
# Epoch 33: Train Loss = 0.0141, Test Loss = 0.0231
# Epoch 34: Train Loss = 0.0142, Test Loss = 0.0109
# Epoch 35: Train Loss = 0.0126, Test Loss = 0.0102
# Epoch 36: Train Loss = 0.0165, Test Loss = 0.0307
# Epoch 37: Train Loss = 0.0134, Test Loss = 0.0091
# Epoch 38: Train Loss = 0.0115, Test Loss = 0.0134
# Epoch 39: Train Loss = 0.0146, Test Loss = 0.0182
# Epoch 40: Train Loss = 0.0147, Test Loss = 0.0122
# Epoch 41: Train Loss = 0.0114, Test Loss = 0.0104
# Epoch 42: Train Loss = 0.0152, Test Loss = 0.0208
# Epoch 43: Train Loss = 0.0129, Test Loss = 0.0128
# Epoch 44: Train Loss = 0.0075, Test Loss = 0.0067
# Epoch 45: Train Loss = 0.0073, Test Loss = 0.0073
# Epoch 46: Train Loss = 0.0079, Test Loss = 0.0073
# Epoch 47: Train Loss = 0.0076, Test Loss = 0.0072
# Epoch 48: Train Loss = 0.0070, Test Loss = 0.0093
# Epoch 49: Train Loss = 0.0094, Test Loss = 0.0113
# Epoch 50: Train Loss = 0.0081, Test Loss = 0.0070
#
# Results for Hidden Size 128
# Epoch 1: Train Loss = 225.5777, Test Loss = 1.4927
# Epoch 2: Train Loss = 1.0430, Test Loss = 0.2931
# Epoch 3: Train Loss = 0.3796, Test Loss = 0.1507
# Epoch 4: Train Loss = 0.3778, Test Loss = 0.1346
# Epoch 5: Train Loss = 0.2201, Test Loss = 0.1204
# Epoch 6: Train Loss = 0.1899, Test Loss = 0.2802
# Epoch 7: Train Loss = 0.2550, Test Loss = 0.0945
# Epoch 8: Train Loss = 0.6390, Test Loss = 3.8158
# Epoch 9: Train Loss = 0.7485, Test Loss = 0.1788
# Epoch 10: Train Loss = 0.1007, Test Loss = 0.0628
# Epoch 11: Train Loss = 0.1812, Test Loss = 0.0650
# Epoch 12: Train Loss = 0.2044, Test Loss = 0.1933
# Epoch 13: Train Loss = 0.4646, Test Loss = 0.8652
# Epoch 14: Train Loss = 0.1878, Test Loss = 0.0947
# Epoch 15: Train Loss = 0.1304, Test Loss = 0.1714
# Epoch 16: Train Loss = 0.4428, Test Loss = 0.3306
# Epoch 17: Train Loss = 0.0431, Test Loss = 0.0215
# Epoch 18: Train Loss = 0.0259, Test Loss = 0.0369
# Epoch 19: Train Loss = 0.0218, Test Loss = 0.0215
# Epoch 20: Train Loss = 0.0302, Test Loss = 0.0511
# Epoch 21: Train Loss = 0.0523, Test Loss = 0.0695
# Epoch 22: Train Loss = 0.0387, Test Loss = 0.1183
# Epoch 23: Train Loss = 0.1669, Test Loss = 0.0841
# Epoch 24: Train Loss = 0.0177, Test Loss = 0.0178
# Epoch 25: Train Loss = 0.0165, Test Loss = 0.0190
# Epoch 26: Train Loss = 0.0187, Test Loss = 0.0155
# Epoch 27: Train Loss = 0.0249, Test Loss = 0.0212
# Epoch 28: Train Loss = 0.0188, Test Loss = 0.0397
# Epoch 29: Train Loss = 0.0258, Test Loss = 0.0334
# Epoch 30: Train Loss = 0.0381, Test Loss = 0.0265
# Epoch 31: Train Loss = 0.0288, Test Loss = 0.0988
# Epoch 32: Train Loss = 0.0292, Test Loss = 0.0303
# Epoch 33: Train Loss = 0.0141, Test Loss = 0.0097
# Epoch 34: Train Loss = 0.0154, Test Loss = 0.0171
# Epoch 35: Train Loss = 0.0134, Test Loss = 0.0230
# Epoch 36: Train Loss = 0.0139, Test Loss = 0.0112
# Epoch 37: Train Loss = 0.0121, Test Loss = 0.0140
# Epoch 38: Train Loss = 0.0140, Test Loss = 0.0141
# Epoch 39: Train Loss = 0.0189, Test Loss = 0.0201
# Epoch 40: Train Loss = 0.0098, Test Loss = 0.0079
# Epoch 41: Train Loss = 0.0095, Test Loss = 0.0104
# Epoch 42: Train Loss = 0.0100, Test Loss = 0.0098
# Epoch 43: Train Loss = 0.0108, Test Loss = 0.0102
# Epoch 44: Train Loss = 0.0101, Test Loss = 0.0082
# Epoch 45: Train Loss = 0.0100, Test Loss = 0.0080
# Epoch 46: Train Loss = 0.0140, Test Loss = 0.0075
# Epoch 47: Train Loss = 0.0091, Test Loss = 0.0090
# Epoch 48: Train Loss = 0.0108, Test Loss = 0.0105
# Epoch 49: Train Loss = 0.0102, Test Loss = 0.0101
# Epoch 50: Train Loss = 0.0103, Test Loss = 0.0143
#
# Results for Pooling max
# Epoch 1: Train Loss = 516.7820, Test Loss = 52.0454
# Epoch 2: Train Loss = 11.8956, Test Loss = 2.4091
# Epoch 3: Train Loss = 0.6468, Test Loss = 0.1952
# Epoch 4: Train Loss = 0.2562, Test Loss = 0.2110
# Epoch 5: Train Loss = 0.2094, Test Loss = 0.2022
# Epoch 6: Train Loss = 0.3175, Test Loss = 0.7670
# Epoch 7: Train Loss = 0.2425, Test Loss = 0.1050
# Epoch 8: Train Loss = 0.1018, Test Loss = 0.1624
# Epoch 9: Train Loss = 0.2126, Test Loss = 0.2669
# Epoch 10: Train Loss = 0.3128, Test Loss = 0.3039
# Epoch 11: Train Loss = 0.1777, Test Loss = 0.1653
# Epoch 12: Train Loss = 0.1918, Test Loss = 0.1863
# Epoch 13: Train Loss = 0.1334, Test Loss = 0.4122
# Epoch 14: Train Loss = 0.0657, Test Loss = 0.0177
# Epoch 15: Train Loss = 0.0379, Test Loss = 0.0344
# Epoch 16: Train Loss = 0.0349, Test Loss = 0.0505
# Epoch 17: Train Loss = 0.0307, Test Loss = 0.0670
# Epoch 18: Train Loss = 0.0367, Test Loss = 0.0334
# Epoch 19: Train Loss = 0.0549, Test Loss = 0.1304
# Epoch 20: Train Loss = 0.2921, Test Loss = 0.0372
# Epoch 21: Train Loss = 0.0165, Test Loss = 0.0126
# Epoch 22: Train Loss = 0.0181, Test Loss = 0.0130
# Epoch 23: Train Loss = 0.0151, Test Loss = 0.0149
# Epoch 24: Train Loss = 0.0165, Test Loss = 0.0120
# Epoch 25: Train Loss = 0.0169, Test Loss = 0.0349
# Epoch 26: Train Loss = 0.0192, Test Loss = 0.0253
# Epoch 27: Train Loss = 0.0182, Test Loss = 0.0390
# Epoch 28: Train Loss = 0.0218, Test Loss = 0.0273
# Epoch 29: Train Loss = 0.0353, Test Loss = 0.0341
# Epoch 30: Train Loss = 0.0234, Test Loss = 0.0206
# Epoch 31: Train Loss = 0.0125, Test Loss = 0.0166
# Epoch 32: Train Loss = 0.0126, Test Loss = 0.0131
# Epoch 33: Train Loss = 0.0127, Test Loss = 0.0135
# Epoch 34: Train Loss = 0.0141, Test Loss = 0.0114
# Epoch 35: Train Loss = 0.0142, Test Loss = 0.0117
# Epoch 36: Train Loss = 0.0123, Test Loss = 0.0127
# Epoch 37: Train Loss = 0.0161, Test Loss = 0.0146
# Epoch 38: Train Loss = 0.0150, Test Loss = 0.0120
# Epoch 39: Train Loss = 0.0153, Test Loss = 0.0130
# Epoch 40: Train Loss = 0.0173, Test Loss = 0.0132
# Epoch 41: Train Loss = 0.0097, Test Loss = 0.0102
# Epoch 42: Train Loss = 0.0098, Test Loss = 0.0088
# Epoch 43: Train Loss = 0.0095, Test Loss = 0.0129
# Epoch 44: Train Loss = 0.0093, Test Loss = 0.0102
# Epoch 45: Train Loss = 0.0092, Test Loss = 0.0100
# Epoch 46: Train Loss = 0.0102, Test Loss = 0.0089
# Epoch 47: Train Loss = 0.0101, Test Loss = 0.0138
# Epoch 48: Train Loss = 0.0103, Test Loss = 0.0231
# Epoch 49: Train Loss = 0.0087, Test Loss = 0.0079
# Epoch 50: Train Loss = 0.0074, Test Loss = 0.0094
#
# Results for Pooling avg
# Epoch 1: Train Loss = 502.4402, Test Loss = 48.6358
# Epoch 2: Train Loss = 11.0192, Test Loss = 1.4553
# Epoch 3: Train Loss = 0.5417, Test Loss = 0.1896
# Epoch 4: Train Loss = 0.1860, Test Loss = 0.2086
# Epoch 5: Train Loss = 0.1503, Test Loss = 0.0702
# Epoch 6: Train Loss = 0.2613, Test Loss = 0.3362
# Epoch 7: Train Loss = 0.4029, Test Loss = 0.0588
# Epoch 8: Train Loss = 0.1244, Test Loss = 0.0935
# Epoch 9: Train Loss = 0.0971, Test Loss = 0.1029
# Epoch 10: Train Loss = 0.1355, Test Loss = 0.1984
# Epoch 11: Train Loss = 0.1572, Test Loss = 0.1120
# Epoch 12: Train Loss = 0.2570, Test Loss = 0.4326
# Epoch 13: Train Loss = 0.2413, Test Loss = 0.1343
# Epoch 14: Train Loss = 0.0264, Test Loss = 0.0254
# Epoch 15: Train Loss = 0.0220, Test Loss = 0.0230
# Epoch 16: Train Loss = 0.0332, Test Loss = 0.0485
# Epoch 17: Train Loss = 0.0314, Test Loss = 0.0317
# Epoch 18: Train Loss = 0.0426, Test Loss = 0.0393
# Epoch 19: Train Loss = 0.0337, Test Loss = 0.0587
# Epoch 20: Train Loss = 0.1244, Test Loss = 0.0502
# Epoch 21: Train Loss = 0.0873, Test Loss = 0.2358
# Epoch 22: Train Loss = 0.0262, Test Loss = 0.0170
# Epoch 23: Train Loss = 0.0165, Test Loss = 0.0176
# Epoch 24: Train Loss = 0.0153, Test Loss = 0.0154
# Epoch 25: Train Loss = 0.0220, Test Loss = 0.0248
# Epoch 26: Train Loss = 0.0207, Test Loss = 0.0177
# Epoch 27: Train Loss = 0.0204, Test Loss = 0.0148
# Epoch 28: Train Loss = 0.0254, Test Loss = 0.0286
# Epoch 29: Train Loss = 0.0288, Test Loss = 0.0365
# Epoch 30: Train Loss = 0.0237, Test Loss = 0.0201
# Epoch 31: Train Loss = 0.0271, Test Loss = 0.0247
# Epoch 32: Train Loss = 0.0218, Test Loss = 0.0120
# Epoch 33: Train Loss = 0.0234, Test Loss = 0.0499
# Epoch 34: Train Loss = 0.0430, Test Loss = 0.0207
# Epoch 35: Train Loss = 0.0537, Test Loss = 0.0216
# Epoch 36: Train Loss = 0.0207, Test Loss = 0.0471
# Epoch 37: Train Loss = 0.0296, Test Loss = 0.0443
# Epoch 38: Train Loss = 0.0330, Test Loss = 0.0313
# Epoch 39: Train Loss = 0.0104, Test Loss = 0.0089
# Epoch 40: Train Loss = 0.0102, Test Loss = 0.0090
# Epoch 41: Train Loss = 0.0097, Test Loss = 0.0102
# Epoch 42: Train Loss = 0.0098, Test Loss = 0.0160
# Epoch 43: Train Loss = 0.0116, Test Loss = 0.0118
# Epoch 44: Train Loss = 0.0126, Test Loss = 0.0095
# Epoch 45: Train Loss = 0.0145, Test Loss = 0.0103
# Epoch 46: Train Loss = 0.0079, Test Loss = 0.0084
# Epoch 47: Train Loss = 0.0078, Test Loss = 0.0076
# Epoch 48: Train Loss = 0.0076, Test Loss = 0.0074
# Epoch 49: Train Loss = 0.0085, Test Loss = 0.0114
# Epoch 50: Train Loss = 0.0082, Test Loss = 0.0092
#
# Results for Epochs 5
# Epoch 1: Train Loss = 547.9692, Test Loss = 59.9184
# Epoch 2: Train Loss = 14.6154, Test Loss = 0.9433
# Epoch 3: Train Loss = 0.4208, Test Loss = 0.1651
# Epoch 4: Train Loss = 0.2376, Test Loss = 0.1115
# Epoch 5: Train Loss = 0.1440, Test Loss = 0.1689
#
# Results for Epochs 50
# Epoch 1: Train Loss = 476.7034, Test Loss = 37.8106
# Epoch 2: Train Loss = 8.9668, Test Loss = 0.5881
# Epoch 3: Train Loss = 0.4675, Test Loss = 0.9600
# Epoch 4: Train Loss = 0.2235, Test Loss = 0.1560
# Epoch 5: Train Loss = 0.2619, Test Loss = 0.2039
# Epoch 6: Train Loss = 0.1680, Test Loss = 0.3151
# Epoch 7: Train Loss = 0.2409, Test Loss = 0.1472
# Epoch 8: Train Loss = 0.2417, Test Loss = 0.0730
# Epoch 9: Train Loss = 0.2620, Test Loss = 0.1049
# Epoch 10: Train Loss = 0.2561, Test Loss = 0.8543
# Epoch 11: Train Loss = 0.2784, Test Loss = 0.2014
# Epoch 12: Train Loss = 0.1919, Test Loss = 0.1150
# Epoch 13: Train Loss = 0.1429, Test Loss = 0.3434
# Epoch 14: Train Loss = 0.2011, Test Loss = 0.3766
# Epoch 15: Train Loss = 0.0390, Test Loss = 0.0272
# Epoch 16: Train Loss = 0.0236, Test Loss = 0.0287
# Epoch 17: Train Loss = 0.0300, Test Loss = 0.0238
# Epoch 18: Train Loss = 0.0337, Test Loss = 0.0463
# Epoch 19: Train Loss = 0.0385, Test Loss = 0.0297
# Epoch 20: Train Loss = 0.0541, Test Loss = 0.0831
# Epoch 21: Train Loss = 0.1991, Test Loss = 0.0899
# Epoch 22: Train Loss = 0.1213, Test Loss = 0.0369
# Epoch 23: Train Loss = 0.0322, Test Loss = 0.0222
# Epoch 24: Train Loss = 0.0358, Test Loss = 0.0373
# Epoch 25: Train Loss = 0.0449, Test Loss = 0.0171
# Epoch 26: Train Loss = 0.0747, Test Loss = 0.2151
# Epoch 27: Train Loss = 0.2111, Test Loss = 0.0504
# Epoch 28: Train Loss = 0.0498, Test Loss = 0.0849
# Epoch 29: Train Loss = 0.0430, Test Loss = 0.0188
# Epoch 30: Train Loss = 0.0393, Test Loss = 0.0243
# Epoch 31: Train Loss = 0.0421, Test Loss = 0.0583
# Epoch 32: Train Loss = 0.0164, Test Loss = 0.0117
# Epoch 33: Train Loss = 0.0134, Test Loss = 0.0163
# Epoch 34: Train Loss = 0.0170, Test Loss = 0.0145
# Epoch 35: Train Loss = 0.0204, Test Loss = 0.0597
# Epoch 36: Train Loss = 0.0237, Test Loss = 0.0190
# Epoch 37: Train Loss = 0.0278, Test Loss = 0.0255
# Epoch 38: Train Loss = 0.0272, Test Loss = 0.0202
# Epoch 39: Train Loss = 0.0106, Test Loss = 0.0094
# Epoch 40: Train Loss = 0.0103, Test Loss = 0.0101
# Epoch 41: Train Loss = 0.0112, Test Loss = 0.0167
# Epoch 42: Train Loss = 0.0140, Test Loss = 0.0164
# Epoch 43: Train Loss = 0.0122, Test Loss = 0.0116
# Epoch 44: Train Loss = 0.0127, Test Loss = 0.0120
# Epoch 45: Train Loss = 0.0123, Test Loss = 0.0218
# Epoch 46: Train Loss = 0.0083, Test Loss = 0.0080
# Epoch 47: Train Loss = 0.0083, Test Loss = 0.0082
# Epoch 48: Train Loss = 0.0085, Test Loss = 0.0077
# Epoch 49: Train Loss = 0.0081, Test Loss = 0.0126
# Epoch 50: Train Loss = 0.0090, Test Loss = 0.0074
#
# Results for Epochs 100
# Epoch 1: Train Loss = 491.1658, Test Loss = 45.8652
# Epoch 2: Train Loss = 10.1651, Test Loss = 0.6490
# Epoch 3: Train Loss = 0.5343, Test Loss = 0.5314
# Epoch 4: Train Loss = 0.2339, Test Loss = 0.1229
# Epoch 5: Train Loss = 0.1759, Test Loss = 0.1353
# Epoch 6: Train Loss = 0.1919, Test Loss = 0.1933
# Epoch 7: Train Loss = 0.2305, Test Loss = 0.3432
# Epoch 8: Train Loss = 0.2909, Test Loss = 0.0975
# Epoch 9: Train Loss = 0.1552, Test Loss = 0.4518
# Epoch 10: Train Loss = 0.3793, Test Loss = 0.4738
# Epoch 11: Train Loss = 0.1597, Test Loss = 0.2163
# Epoch 12: Train Loss = 0.2424, Test Loss = 0.1165
# Epoch 13: Train Loss = 0.1496, Test Loss = 0.3653
# Epoch 14: Train Loss = 0.1833, Test Loss = 0.1645
# Epoch 15: Train Loss = 0.0285, Test Loss = 0.0287
# Epoch 16: Train Loss = 0.0236, Test Loss = 0.0240
# Epoch 17: Train Loss = 0.0203, Test Loss = 0.0225
# Epoch 18: Train Loss = 0.0261, Test Loss = 0.0321
# Epoch 19: Train Loss = 0.0530, Test Loss = 0.1953
# Epoch 20: Train Loss = 0.0800, Test Loss = 0.0424
# Epoch 21: Train Loss = 0.0368, Test Loss = 0.0384
# Epoch 22: Train Loss = 0.0721, Test Loss = 0.0251
# Epoch 23: Train Loss = 0.0498, Test Loss = 0.0305
# Epoch 24: Train Loss = 0.0140, Test Loss = 0.0143
# Epoch 25: Train Loss = 0.0163, Test Loss = 0.0133
# Epoch 26: Train Loss = 0.0230, Test Loss = 0.0251
# Epoch 27: Train Loss = 0.0143, Test Loss = 0.0110
# Epoch 28: Train Loss = 0.0166, Test Loss = 0.0163
# Epoch 29: Train Loss = 0.0186, Test Loss = 0.0164
# Epoch 30: Train Loss = 0.0245, Test Loss = 0.0645
# Epoch 31: Train Loss = 0.0390, Test Loss = 0.0156
# Epoch 32: Train Loss = 0.0253, Test Loss = 0.0152
# Epoch 33: Train Loss = 0.0338, Test Loss = 0.0167
# Epoch 34: Train Loss = 0.0094, Test Loss = 0.0087
# Epoch 35: Train Loss = 0.0090, Test Loss = 0.0080
# Epoch 36: Train Loss = 0.0103, Test Loss = 0.0080
# Epoch 37: Train Loss = 0.0102, Test Loss = 0.0161
# Epoch 38: Train Loss = 0.0097, Test Loss = 0.0093
# Epoch 39: Train Loss = 0.0103, Test Loss = 0.0099
# Epoch 40: Train Loss = 0.0103, Test Loss = 0.0108
# Epoch 41: Train Loss = 0.0118, Test Loss = 0.0126
# Epoch 42: Train Loss = 0.0073, Test Loss = 0.0074
# Epoch 43: Train Loss = 0.0076, Test Loss = 0.0069
# Epoch 44: Train Loss = 0.0083, Test Loss = 0.0087
# Epoch 45: Train Loss = 0.0074, Test Loss = 0.0067
# Epoch 46: Train Loss = 0.0082, Test Loss = 0.0070
# Epoch 47: Train Loss = 0.0071, Test Loss = 0.0097
# Epoch 48: Train Loss = 0.0080, Test Loss = 0.0081
# Epoch 49: Train Loss = 0.0087, Test Loss = 0.0088
# Epoch 50: Train Loss = 0.0073, Test Loss = 0.0081
# Epoch 51: Train Loss = 0.0088, Test Loss = 0.0085
# Epoch 52: Train Loss = 0.0060, Test Loss = 0.0065
# Epoch 53: Train Loss = 0.0058, Test Loss = 0.0068
# Epoch 54: Train Loss = 0.0059, Test Loss = 0.0062
# Epoch 55: Train Loss = 0.0062, Test Loss = 0.0063
# Epoch 56: Train Loss = 0.0064, Test Loss = 0.0079
# Epoch 57: Train Loss = 0.0063, Test Loss = 0.0068
# Epoch 58: Train Loss = 0.0059, Test Loss = 0.0058
# Epoch 59: Train Loss = 0.0061, Test Loss = 0.0087
# Epoch 60: Train Loss = 0.0062, Test Loss = 0.0067
# Epoch 61: Train Loss = 0.0064, Test Loss = 0.0062
# Epoch 62: Train Loss = 0.0061, Test Loss = 0.0058
# Epoch 63: Train Loss = 0.0061, Test Loss = 0.0056
# Epoch 64: Train Loss = 0.0060, Test Loss = 0.0072
# Epoch 65: Train Loss = 0.0067, Test Loss = 0.0057
# Epoch 66: Train Loss = 0.0058, Test Loss = 0.0070
# Epoch 67: Train Loss = 0.0058, Test Loss = 0.0061
# Epoch 68: Train Loss = 0.0061, Test Loss = 0.0064
# Epoch 69: Train Loss = 0.0061, Test Loss = 0.0060
# Epoch 70: Train Loss = 0.0049, Test Loss = 0.0054
# Epoch 71: Train Loss = 0.0051, Test Loss = 0.0059
# Epoch 72: Train Loss = 0.0049, Test Loss = 0.0054
# Epoch 73: Train Loss = 0.0049, Test Loss = 0.0052
# Epoch 74: Train Loss = 0.0051, Test Loss = 0.0054
# Epoch 75: Train Loss = 0.0051, Test Loss = 0.0058
# Epoch 76: Train Loss = 0.0050, Test Loss = 0.0058
# Epoch 77: Train Loss = 0.0050, Test Loss = 0.0057
# Epoch 78: Train Loss = 0.0050, Test Loss = 0.0062
# Epoch 79: Train Loss = 0.0051, Test Loss = 0.0054
# Epoch 80: Train Loss = 0.0046, Test Loss = 0.0051
# Epoch 81: Train Loss = 0.0045, Test Loss = 0.0051
# Epoch 82: Train Loss = 0.0046, Test Loss = 0.0054
# Epoch 83: Train Loss = 0.0045, Test Loss = 0.0051
# Epoch 84: Train Loss = 0.0045, Test Loss = 0.0051
# Epoch 85: Train Loss = 0.0045, Test Loss = 0.0052
# Epoch 86: Train Loss = 0.0046, Test Loss = 0.0051
# Epoch 87: Train Loss = 0.0046, Test Loss = 0.0049
# Epoch 88: Train Loss = 0.0045, Test Loss = 0.0050
# Epoch 89: Train Loss = 0.0045, Test Loss = 0.0054
# Epoch 90: Train Loss = 0.0046, Test Loss = 0.0051
# Epoch 91: Train Loss = 0.0047, Test Loss = 0.0054
# Epoch 92: Train Loss = 0.0045, Test Loss = 0.0055
# Epoch 93: Train Loss = 0.0045, Test Loss = 0.0049
# Epoch 94: Train Loss = 0.0046, Test Loss = 0.0050
# Epoch 95: Train Loss = 0.0046, Test Loss = 0.0062
# Epoch 96: Train Loss = 0.0046, Test Loss = 0.0052
# Epoch 97: Train Loss = 0.0045, Test Loss = 0.0051
# Epoch 98: Train Loss = 0.0046, Test Loss = 0.0050
# Epoch 99: Train Loss = 0.0045, Test Loss = 0.0050
# Epoch 100: Train Loss = 0.0043, Test Loss = 0.0051
#
# Results for Epochs 250
# Epoch 1: Train Loss = 494.6895, Test Loss = 43.0294
# Epoch 2: Train Loss = 10.0645, Test Loss = 0.4215
# Epoch 3: Train Loss = 0.3879, Test Loss = 0.3003
# Epoch 4: Train Loss = 0.1968, Test Loss = 0.1094
# Epoch 5: Train Loss = 0.1251, Test Loss = 0.3907
# Epoch 6: Train Loss = 0.1656, Test Loss = 0.0474
# Epoch 7: Train Loss = 0.4960, Test Loss = 0.2930
# Epoch 8: Train Loss = 0.2447, Test Loss = 0.1378
# Epoch 9: Train Loss = 0.1052, Test Loss = 0.2648
# Epoch 10: Train Loss = 0.1628, Test Loss = 0.0971
# Epoch 11: Train Loss = 0.1454, Test Loss = 0.0579
# Epoch 12: Train Loss = 0.1292, Test Loss = 0.7925
# Epoch 13: Train Loss = 0.0681, Test Loss = 0.0168
# Epoch 14: Train Loss = 0.0258, Test Loss = 0.0228
# Epoch 15: Train Loss = 0.0301, Test Loss = 0.0175
# Epoch 16: Train Loss = 0.0317, Test Loss = 0.0196
# Epoch 17: Train Loss = 0.0365, Test Loss = 0.0474
# Epoch 18: Train Loss = 0.0415, Test Loss = 0.0475
# Epoch 19: Train Loss = 0.0567, Test Loss = 0.0343
# Epoch 20: Train Loss = 0.0150, Test Loss = 0.0120
# Epoch 21: Train Loss = 0.0158, Test Loss = 0.0099
# Epoch 22: Train Loss = 0.0175, Test Loss = 0.0119
# Epoch 23: Train Loss = 0.0313, Test Loss = 0.0297
# Epoch 24: Train Loss = 0.0186, Test Loss = 0.0248
# Epoch 25: Train Loss = 0.0261, Test Loss = 0.0771
# Epoch 26: Train Loss = 0.0296, Test Loss = 0.0382
# Epoch 27: Train Loss = 0.0238, Test Loss = 0.0359
# Epoch 28: Train Loss = 0.0109, Test Loss = 0.0101
# Epoch 29: Train Loss = 0.0115, Test Loss = 0.0083
# Epoch 30: Train Loss = 0.0116, Test Loss = 0.0111
# Epoch 31: Train Loss = 0.0118, Test Loss = 0.0127
# Epoch 32: Train Loss = 0.0121, Test Loss = 0.0125
# Epoch 33: Train Loss = 0.0123, Test Loss = 0.0122
# Epoch 34: Train Loss = 0.0133, Test Loss = 0.0088
# Epoch 35: Train Loss = 0.0115, Test Loss = 0.0138
# Epoch 36: Train Loss = 0.0084, Test Loss = 0.0078
# Epoch 37: Train Loss = 0.0086, Test Loss = 0.0102
# Epoch 38: Train Loss = 0.0086, Test Loss = 0.0072
# Epoch 39: Train Loss = 0.0089, Test Loss = 0.0104
# Epoch 40: Train Loss = 0.0084, Test Loss = 0.0069
# Epoch 41: Train Loss = 0.0088, Test Loss = 0.0097
# Epoch 42: Train Loss = 0.0085, Test Loss = 0.0078
# Epoch 43: Train Loss = 0.0090, Test Loss = 0.0151
# Epoch 44: Train Loss = 0.0089, Test Loss = 0.0091
# Epoch 45: Train Loss = 0.0089, Test Loss = 0.0083
# Epoch 46: Train Loss = 0.0095, Test Loss = 0.0082
# Epoch 47: Train Loss = 0.0066, Test Loss = 0.0058
# Epoch 48: Train Loss = 0.0064, Test Loss = 0.0080
# Epoch 49: Train Loss = 0.0066, Test Loss = 0.0060
# Epoch 50: Train Loss = 0.0067, Test Loss = 0.0070
# Epoch 51: Train Loss = 0.0069, Test Loss = 0.0089
# Epoch 52: Train Loss = 0.0067, Test Loss = 0.0093
# Epoch 53: Train Loss = 0.0068, Test Loss = 0.0067
# Epoch 54: Train Loss = 0.0057, Test Loss = 0.0057
# Epoch 55: Train Loss = 0.0058, Test Loss = 0.0059
# Epoch 56: Train Loss = 0.0057, Test Loss = 0.0056
# Epoch 57: Train Loss = 0.0057, Test Loss = 0.0058
# Epoch 58: Train Loss = 0.0057, Test Loss = 0.0067
# Epoch 59: Train Loss = 0.0057, Test Loss = 0.0059
# Epoch 60: Train Loss = 0.0057, Test Loss = 0.0057
# Epoch 61: Train Loss = 0.0058, Test Loss = 0.0055
# Epoch 62: Train Loss = 0.0057, Test Loss = 0.0063
# Epoch 63: Train Loss = 0.0058, Test Loss = 0.0067
# Epoch 64: Train Loss = 0.0057, Test Loss = 0.0058
# Epoch 65: Train Loss = 0.0058, Test Loss = 0.0060
# Epoch 66: Train Loss = 0.0059, Test Loss = 0.0069
# Epoch 67: Train Loss = 0.0057, Test Loss = 0.0062
# Epoch 68: Train Loss = 0.0052, Test Loss = 0.0053
# Epoch 69: Train Loss = 0.0051, Test Loss = 0.0051
# Epoch 70: Train Loss = 0.0052, Test Loss = 0.0052
# Epoch 71: Train Loss = 0.0051, Test Loss = 0.0052
# Epoch 72: Train Loss = 0.0052, Test Loss = 0.0051
# Epoch 73: Train Loss = 0.0052, Test Loss = 0.0056
# Epoch 74: Train Loss = 0.0052, Test Loss = 0.0053
# Epoch 75: Train Loss = 0.0053, Test Loss = 0.0056
# Epoch 76: Train Loss = 0.0052, Test Loss = 0.0052
# Epoch 77: Train Loss = 0.0052, Test Loss = 0.0054
# Epoch 78: Train Loss = 0.0051, Test Loss = 0.0050
# Epoch 79: Train Loss = 0.0052, Test Loss = 0.0053
# Epoch 80: Train Loss = 0.0051, Test Loss = 0.0052
# Epoch 81: Train Loss = 0.0051, Test Loss = 0.0052
# Epoch 82: Train Loss = 0.0051, Test Loss = 0.0051
# Epoch 83: Train Loss = 0.0050, Test Loss = 0.0056
# Epoch 84: Train Loss = 0.0051, Test Loss = 0.0051
# Epoch 85: Train Loss = 0.0048, Test Loss = 0.0049
# Epoch 86: Train Loss = 0.0048, Test Loss = 0.0050
# Epoch 87: Train Loss = 0.0049, Test Loss = 0.0050
# Epoch 88: Train Loss = 0.0048, Test Loss = 0.0050
# Epoch 89: Train Loss = 0.0048, Test Loss = 0.0051
# Epoch 90: Train Loss = 0.0048, Test Loss = 0.0049
# Epoch 91: Train Loss = 0.0048, Test Loss = 0.0049
# Epoch 92: Train Loss = 0.0048, Test Loss = 0.0049
# Epoch 93: Train Loss = 0.0048, Test Loss = 0.0048
# Epoch 94: Train Loss = 0.0048, Test Loss = 0.0052
# Epoch 95: Train Loss = 0.0048, Test Loss = 0.0051
# Epoch 96: Train Loss = 0.0048, Test Loss = 0.0049
# Epoch 97: Train Loss = 0.0048, Test Loss = 0.0049
# Epoch 98: Train Loss = 0.0047, Test Loss = 0.0048
# Epoch 99: Train Loss = 0.0048, Test Loss = 0.0049
# Epoch 100: Train Loss = 0.0047, Test Loss = 0.0048
# Epoch 101: Train Loss = 0.0046, Test Loss = 0.0048
# Epoch 102: Train Loss = 0.0047, Test Loss = 0.0048
# Epoch 103: Train Loss = 0.0047, Test Loss = 0.0050
# Epoch 104: Train Loss = 0.0046, Test Loss = 0.0048
# Epoch 105: Train Loss = 0.0046, Test Loss = 0.0049
# Epoch 106: Train Loss = 0.0047, Test Loss = 0.0048
# Epoch 107: Train Loss = 0.0046, Test Loss = 0.0048
# Epoch 108: Train Loss = 0.0046, Test Loss = 0.0051
# Epoch 109: Train Loss = 0.0046, Test Loss = 0.0048
# Epoch 110: Train Loss = 0.0047, Test Loss = 0.0049
# Epoch 111: Train Loss = 0.0046, Test Loss = 0.0048
# Epoch 112: Train Loss = 0.0046, Test Loss = 0.0047
# Epoch 113: Train Loss = 0.0046, Test Loss = 0.0048
# Epoch 114: Train Loss = 0.0046, Test Loss = 0.0048
# Epoch 115: Train Loss = 0.0046, Test Loss = 0.0048
# Epoch 116: Train Loss = 0.0046, Test Loss = 0.0048
# Epoch 117: Train Loss = 0.0046, Test Loss = 0.0048
# Epoch 118: Train Loss = 0.0046, Test Loss = 0.0048
# Epoch 119: Train Loss = 0.0045, Test Loss = 0.0047
# Epoch 120: Train Loss = 0.0046, Test Loss = 0.0048
# Epoch 121: Train Loss = 0.0045, Test Loss = 0.0047
# Epoch 122: Train Loss = 0.0046, Test Loss = 0.0048
# Epoch 123: Train Loss = 0.0046, Test Loss = 0.0048
# Epoch 124: Train Loss = 0.0045, Test Loss = 0.0047
# Epoch 125: Train Loss = 0.0045, Test Loss = 0.0048
# Epoch 126: Train Loss = 0.0045, Test Loss = 0.0047
# Epoch 127: Train Loss = 0.0045, Test Loss = 0.0047
# Epoch 128: Train Loss = 0.0045, Test Loss = 0.0047
# Epoch 129: Train Loss = 0.0045, Test Loss = 0.0047
# Epoch 130: Train Loss = 0.0045, Test Loss = 0.0048
# Epoch 131: Train Loss = 0.0045, Test Loss = 0.0047
#
# Results for Epochs 350
# Epoch 1: Train Loss = 432.5442, Test Loss = 27.6210
# Epoch 2: Train Loss = 6.3068, Test Loss = 0.6674
# Epoch 3: Train Loss = 0.4050, Test Loss = 0.1704
# Epoch 4: Train Loss = 0.1677, Test Loss = 0.0823
# Epoch 5: Train Loss = 0.2088, Test Loss = 1.1194
# Epoch 6: Train Loss = 0.1794, Test Loss = 0.0887
# Epoch 7: Train Loss = 0.1968, Test Loss = 0.1624
# Epoch 8: Train Loss = 0.2902, Test Loss = 0.1161
# Epoch 9: Train Loss = 0.1517, Test Loss = 0.1671
# Epoch 10: Train Loss = 0.8800, Test Loss = 0.4105
# Epoch 11: Train Loss = 0.0487, Test Loss = 0.0311
# Epoch 12: Train Loss = 0.0282, Test Loss = 0.0267
# Epoch 13: Train Loss = 0.0343, Test Loss = 0.0275
# Epoch 14: Train Loss = 0.0277, Test Loss = 0.0251
# Epoch 15: Train Loss = 0.0274, Test Loss = 0.0190
# Epoch 16: Train Loss = 0.0373, Test Loss = 0.0759
# Epoch 17: Train Loss = 0.0390, Test Loss = 0.0277
# Epoch 18: Train Loss = 0.0317, Test Loss = 0.0263
# Epoch 19: Train Loss = 0.0380, Test Loss = 0.0575
# Epoch 20: Train Loss = 0.0545, Test Loss = 0.0994
# Epoch 21: Train Loss = 0.0951, Test Loss = 0.0606
# Epoch 22: Train Loss = 0.0178, Test Loss = 0.0135
# Epoch 23: Train Loss = 0.0163, Test Loss = 0.0131
# Epoch 24: Train Loss = 0.0156, Test Loss = 0.0165
# Epoch 25: Train Loss = 0.0189, Test Loss = 0.0193
# Epoch 26: Train Loss = 0.0169, Test Loss = 0.0260
# Epoch 27: Train Loss = 0.0209, Test Loss = 0.0172
# Epoch 28: Train Loss = 0.0306, Test Loss = 0.0130
# Epoch 29: Train Loss = 0.0244, Test Loss = 0.0201
# Epoch 30: Train Loss = 0.0439, Test Loss = 0.0300
# Epoch 31: Train Loss = 0.0331, Test Loss = 0.0247
# Epoch 32: Train Loss = 0.0235, Test Loss = 0.0267
# Epoch 33: Train Loss = 0.0565, Test Loss = 0.0282
# Epoch 34: Train Loss = 0.0327, Test Loss = 0.0146
# Epoch 35: Train Loss = 0.0109, Test Loss = 0.0085
# Epoch 36: Train Loss = 0.0108, Test Loss = 0.0103
# Epoch 37: Train Loss = 0.0118, Test Loss = 0.0108
# Epoch 38: Train Loss = 0.0111, Test Loss = 0.0109
# Epoch 39: Train Loss = 0.0132, Test Loss = 0.0251
# Epoch 40: Train Loss = 0.0124, Test Loss = 0.0141
# Epoch 41: Train Loss = 0.0143, Test Loss = 0.0165
# Epoch 42: Train Loss = 0.0081, Test Loss = 0.0072
# Epoch 43: Train Loss = 0.0076, Test Loss = 0.0078
# Epoch 44: Train Loss = 0.0083, Test Loss = 0.0075
# Epoch 45: Train Loss = 0.0088, Test Loss = 0.0091
# Epoch 46: Train Loss = 0.0087, Test Loss = 0.0102
# Epoch 47: Train Loss = 0.0085, Test Loss = 0.0124
# Epoch 48: Train Loss = 0.0091, Test Loss = 0.0090
# Epoch 49: Train Loss = 0.0070, Test Loss = 0.0084
# Epoch 50: Train Loss = 0.0067, Test Loss = 0.0073
# Epoch 51: Train Loss = 0.0069, Test Loss = 0.0068
# Epoch 52: Train Loss = 0.0073, Test Loss = 0.0071
# Epoch 53: Train Loss = 0.0070, Test Loss = 0.0068
# Epoch 54: Train Loss = 0.0070, Test Loss = 0.0076
# Epoch 55: Train Loss = 0.0070, Test Loss = 0.0076
# Epoch 56: Train Loss = 0.0073, Test Loss = 0.0089
# Epoch 57: Train Loss = 0.0077, Test Loss = 0.0062
# Epoch 58: Train Loss = 0.0071, Test Loss = 0.0063
# Epoch 59: Train Loss = 0.0070, Test Loss = 0.0064
# Epoch 60: Train Loss = 0.0070, Test Loss = 0.0084
# Epoch 61: Train Loss = 0.0066, Test Loss = 0.0063
# Epoch 62: Train Loss = 0.0073, Test Loss = 0.0075
# Epoch 63: Train Loss = 0.0069, Test Loss = 0.0080
# Epoch 64: Train Loss = 0.0060, Test Loss = 0.0061
# Epoch 65: Train Loss = 0.0059, Test Loss = 0.0058
# Epoch 66: Train Loss = 0.0058, Test Loss = 0.0068
# Epoch 67: Train Loss = 0.0058, Test Loss = 0.0061
# Epoch 68: Train Loss = 0.0059, Test Loss = 0.0059
# Epoch 69: Train Loss = 0.0059, Test Loss = 0.0059
# Epoch 70: Train Loss = 0.0059, Test Loss = 0.0064
# Epoch 71: Train Loss = 0.0058, Test Loss = 0.0058
# Epoch 72: Train Loss = 0.0054, Test Loss = 0.0057
# Epoch 73: Train Loss = 0.0054, Test Loss = 0.0057
# Epoch 74: Train Loss = 0.0054, Test Loss = 0.0060
# Epoch 75: Train Loss = 0.0054, Test Loss = 0.0055
# Epoch 76: Train Loss = 0.0054, Test Loss = 0.0062
# Epoch 77: Train Loss = 0.0054, Test Loss = 0.0058
# Epoch 78: Train Loss = 0.0054, Test Loss = 0.0061
# Epoch 79: Train Loss = 0.0054, Test Loss = 0.0056
# Epoch 80: Train Loss = 0.0054, Test Loss = 0.0056
# Epoch 81: Train Loss = 0.0053, Test Loss = 0.0055
# Epoch 82: Train Loss = 0.0051, Test Loss = 0.0055
# Epoch 83: Train Loss = 0.0051, Test Loss = 0.0054
# Epoch 84: Train Loss = 0.0051, Test Loss = 0.0055
# Epoch 85: Train Loss = 0.0052, Test Loss = 0.0056
# Epoch 86: Train Loss = 0.0051, Test Loss = 0.0055
# Epoch 87: Train Loss = 0.0051, Test Loss = 0.0056
# Epoch 88: Train Loss = 0.0051, Test Loss = 0.0056
# Epoch 89: Train Loss = 0.0051, Test Loss = 0.0058
# Epoch 90: Train Loss = 0.0050, Test Loss = 0.0054
# Epoch 91: Train Loss = 0.0050, Test Loss = 0.0054
# Epoch 92: Train Loss = 0.0050, Test Loss = 0.0053
# Epoch 93: Train Loss = 0.0050, Test Loss = 0.0054
# Epoch 94: Train Loss = 0.0050, Test Loss = 0.0053
# Epoch 95: Train Loss = 0.0050, Test Loss = 0.0054
# Epoch 96: Train Loss = 0.0050, Test Loss = 0.0054
# Epoch 97: Train Loss = 0.0050, Test Loss = 0.0052
# Epoch 98: Train Loss = 0.0050, Test Loss = 0.0053
# Epoch 99: Train Loss = 0.0050, Test Loss = 0.0054
# Epoch 100: Train Loss = 0.0049, Test Loss = 0.0053
# Epoch 101: Train Loss = 0.0050, Test Loss = 0.0055
# Epoch 102: Train Loss = 0.0049, Test Loss = 0.0053
# Epoch 103: Train Loss = 0.0049, Test Loss = 0.0053
# Epoch 104: Train Loss = 0.0049, Test Loss = 0.0052
# Epoch 105: Train Loss = 0.0049, Test Loss = 0.0053
# Epoch 106: Train Loss = 0.0049, Test Loss = 0.0053
# Epoch 107: Train Loss = 0.0049, Test Loss = 0.0053
#
# Results for Optimizer SGD
# Epoch 1: Train Loss = 154.0891, Test Loss = 3.2433
# Epoch 2: Train Loss = 3.5165, Test Loss = 2.9143
# Epoch 3: Train Loss = 2.0048, Test Loss = 0.7923
# Epoch 4: Train Loss = 1.1738, Test Loss = 0.6309
# Epoch 5: Train Loss = 0.8842, Test Loss = 0.6689
# Epoch 6: Train Loss = 0.6381, Test Loss = 0.4203
# Epoch 7: Train Loss = 0.6118, Test Loss = 0.2801
# Epoch 8: Train Loss = 0.5042, Test Loss = 0.3243
# Epoch 9: Train Loss = 0.4035, Test Loss = 0.4727
# Epoch 10: Train Loss = 0.3452, Test Loss = 0.2198
# Epoch 11: Train Loss = 0.2673, Test Loss = 0.1419
# Epoch 12: Train Loss = 0.3037, Test Loss = 0.1513
# Epoch 13: Train Loss = 0.2163, Test Loss = 0.1165
# Epoch 14: Train Loss = 0.1816, Test Loss = 0.1284
# Epoch 15: Train Loss = 0.1843, Test Loss = 0.1080
# Epoch 16: Train Loss = 0.1417, Test Loss = 0.1649
# Epoch 17: Train Loss = 0.1375, Test Loss = 0.2106
# Epoch 18: Train Loss = 0.1293, Test Loss = 0.1620
# Epoch 19: Train Loss = 0.1260, Test Loss = 0.0698
# Epoch 20: Train Loss = 0.1076, Test Loss = 0.0941
# Epoch 21: Train Loss = 0.0943, Test Loss = 0.0830
# Epoch 22: Train Loss = 0.1008, Test Loss = 0.0785
# Epoch 23: Train Loss = 0.0835, Test Loss = 0.0900
# Epoch 24: Train Loss = 0.0854, Test Loss = 0.0543
# Epoch 25: Train Loss = 0.0877, Test Loss = 0.1074
# Epoch 26: Train Loss = 0.0773, Test Loss = 0.0998
# Epoch 27: Train Loss = 0.0754, Test Loss = 0.0486
# Epoch 28: Train Loss = 0.0938, Test Loss = 0.0508
# Epoch 29: Train Loss = 0.0758, Test Loss = 0.0524
# Epoch 30: Train Loss = 0.0706, Test Loss = 0.0544
# Epoch 31: Train Loss = 0.0665, Test Loss = 0.0420
# Epoch 32: Train Loss = 0.0602, Test Loss = 0.0534
# Epoch 33: Train Loss = 0.0530, Test Loss = 0.0504
# Epoch 34: Train Loss = 0.0682, Test Loss = 0.1407
# Epoch 35: Train Loss = 0.0576, Test Loss = 0.0460
# Epoch 36: Train Loss = 0.0624, Test Loss = 0.0486
# Epoch 37: Train Loss = 0.0621, Test Loss = 0.0514
# Epoch 38: Train Loss = 0.0293, Test Loss = 0.0346
# Epoch 39: Train Loss = 0.0284, Test Loss = 0.0396
# Epoch 40: Train Loss = 0.0283, Test Loss = 0.0335
# Epoch 41: Train Loss = 0.0281, Test Loss = 0.0304
# Epoch 42: Train Loss = 0.0275, Test Loss = 0.0322
# Epoch 43: Train Loss = 0.0269, Test Loss = 0.0303
# Epoch 44: Train Loss = 0.0266, Test Loss = 0.0296
# Epoch 45: Train Loss = 0.0260, Test Loss = 0.0308
# Epoch 46: Train Loss = 0.0262, Test Loss = 0.0300
# Epoch 47: Train Loss = 0.0261, Test Loss = 0.0298
# Epoch 48: Train Loss = 0.0254, Test Loss = 0.0331
# Epoch 49: Train Loss = 0.0244, Test Loss = 0.0281
# Epoch 50: Train Loss = 0.0251, Test Loss = 0.0276
#
# Results for Optimizer RMSProp
# Epoch 1: Train Loss = 203.4203, Test Loss = 6.9226
# Epoch 2: Train Loss = 6.3002, Test Loss = 2.7366
# Epoch 3: Train Loss = 5.4857, Test Loss = 1.1097
# Epoch 4: Train Loss = 4.0979, Test Loss = 1.0256
# Epoch 5: Train Loss = 3.9887, Test Loss = 0.6634
# Epoch 6: Train Loss = 3.6407, Test Loss = 10.7533
# Epoch 7: Train Loss = 3.1123, Test Loss = 19.7452
# Epoch 8: Train Loss = 2.9197, Test Loss = 0.5504
# Epoch 9: Train Loss = 2.1715, Test Loss = 2.8233
# Epoch 10: Train Loss = 2.3277, Test Loss = 1.7939
# Epoch 11: Train Loss = 2.5173, Test Loss = 0.4781
# Epoch 12: Train Loss = 1.9816, Test Loss = 0.7124
# Epoch 13: Train Loss = 1.6285, Test Loss = 1.0247
# Epoch 14: Train Loss = 1.8075, Test Loss = 0.3269
# Epoch 15: Train Loss = 1.7195, Test Loss = 0.6294
# Epoch 16: Train Loss = 1.4966, Test Loss = 0.1444
# Epoch 17: Train Loss = 1.5042, Test Loss = 1.9627
# Epoch 18: Train Loss = 1.7697, Test Loss = 0.1815
# Epoch 19: Train Loss = 1.4232, Test Loss = 0.5462
# Epoch 20: Train Loss = 1.2470, Test Loss = 0.4144
# Epoch 21: Train Loss = 1.1879, Test Loss = 13.3565
# Epoch 22: Train Loss = 1.3981, Test Loss = 0.3464
# Epoch 23: Train Loss = 0.1670, Test Loss = 0.1790
# Epoch 24: Train Loss = 0.3817, Test Loss = 1.2435
# Epoch 25: Train Loss = 0.3135, Test Loss = 0.3716
# Epoch 26: Train Loss = 0.3528, Test Loss = 0.4720
#
# Results for Optimizer Adam
# Epoch 1: Train Loss = 528.5403, Test Loss = 54.5864
# Epoch 2: Train Loss = 12.7670, Test Loss = 0.6799
# Epoch 3: Train Loss = 0.4079, Test Loss = 0.1255
# Epoch 4: Train Loss = 0.1839, Test Loss = 0.0544
# Epoch 5: Train Loss = 0.2056, Test Loss = 0.2447
# Epoch 6: Train Loss = 0.2005, Test Loss = 0.0726
# Epoch 7: Train Loss = 0.2328, Test Loss = 0.5295
# Epoch 8: Train Loss = 0.4522, Test Loss = 0.2455
# Epoch 9: Train Loss = 0.0669, Test Loss = 0.0886
# Epoch 10: Train Loss = 0.0946, Test Loss = 0.0542
# Epoch 11: Train Loss = 0.1158, Test Loss = 0.0425
# Epoch 12: Train Loss = 0.2454, Test Loss = 1.4761
# Epoch 13: Train Loss = 0.6544, Test Loss = 0.0276
# Epoch 14: Train Loss = 0.0647, Test Loss = 0.0582
# Epoch 15: Train Loss = 0.0576, Test Loss = 0.0310
# Epoch 16: Train Loss = 0.0881, Test Loss = 0.2807
# Epoch 17: Train Loss = 0.1236, Test Loss = 0.1084
# Epoch 18: Train Loss = 0.1265, Test Loss = 0.0978
# Epoch 19: Train Loss = 0.0682, Test Loss = 0.1184
# Epoch 20: Train Loss = 0.0235, Test Loss = 0.0320
# Epoch 21: Train Loss = 0.0176, Test Loss = 0.0195
# Epoch 22: Train Loss = 0.0183, Test Loss = 0.0334
# Epoch 23: Train Loss = 0.0191, Test Loss = 0.0307
# Epoch 24: Train Loss = 0.0387, Test Loss = 0.0703
# Epoch 25: Train Loss = 0.0537, Test Loss = 0.0526
# Epoch 26: Train Loss = 0.0421, Test Loss = 0.0352
# Epoch 27: Train Loss = 0.0319, Test Loss = 0.0392
# Epoch 28: Train Loss = 0.0110, Test Loss = 0.0094
# Epoch 29: Train Loss = 0.0105, Test Loss = 0.0154
# Epoch 30: Train Loss = 0.0111, Test Loss = 0.0114
# Epoch 31: Train Loss = 0.0114, Test Loss = 0.0246
# Epoch 32: Train Loss = 0.0139, Test Loss = 0.0172
# Epoch 33: Train Loss = 0.0124, Test Loss = 0.0216
# Epoch 34: Train Loss = 0.0209, Test Loss = 0.0694
# Epoch 35: Train Loss = 0.0109, Test Loss = 0.0085
# Epoch 36: Train Loss = 0.0075, Test Loss = 0.0142
# Epoch 37: Train Loss = 0.0076, Test Loss = 0.0062
# Epoch 38: Train Loss = 0.0081, Test Loss = 0.0075
# Epoch 39: Train Loss = 0.0086, Test Loss = 0.0109
# Epoch 40: Train Loss = 0.0090, Test Loss = 0.0208
# Epoch 41: Train Loss = 0.0089, Test Loss = 0.0094
# Epoch 42: Train Loss = 0.0094, Test Loss = 0.0101
# Epoch 43: Train Loss = 0.0100, Test Loss = 0.0213
# Epoch 44: Train Loss = 0.0061, Test Loss = 0.0060
# Epoch 45: Train Loss = 0.0063, Test Loss = 0.0071
# Epoch 46: Train Loss = 0.0055, Test Loss = 0.0058
# Epoch 47: Train Loss = 0.0058, Test Loss = 0.0058
# Epoch 48: Train Loss = 0.0067, Test Loss = 0.0087
# Epoch 49: Train Loss = 0.0060, Test Loss = 0.0076
# Epoch 50: Train Loss = 0.0061, Test Loss = 0.0067

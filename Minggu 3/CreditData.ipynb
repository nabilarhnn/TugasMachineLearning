# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# Load the dataset
dataset = pd.read_csv("C:\\Users\\user\\Downloads\\CreditDataset.csv")

# Display basic information about the dataset
print(dataset.info())
print(dataset.describe())
print(dataset.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      1000 non-null   object
#  1   x2      1000 non-null   int64
#  2   x3      1000 non-null   object
#  3   x4      1000 non-null   object
#  4   x5      1000 non-null   int64
#  5   x6      1000 non-null   object
#  6   x7      1000 non-null   object
#  7   x8      1000 non-null   int64
#  8   x9      1000 non-null   object
#  9   x10     1000 non-null   object
#  10  x11     1000 non-null   int64
#  11  x12     1000 non-null   object
#  12  x13     1000 non-null   int64
#  13  x14     1000 non-null   object
#  14  x15     1000 non-null   object
#  15  x16     1000 non-null   int64
#  16  x17     1000 non-null   object
#  17  x18     1000 non-null   int64
#  18  x19     1000 non-null   object
#  19  x20     1000 non-null   object
#  20  Class   1000 non-null   int64
# ...

# %%
# First, check which columns are numeric and which are non-numeric
numeric_columns = X.select_dtypes(include=[np.number]).columns
non_numeric_columns = X.select_dtypes(exclude=[np.number]).columns

# Now, fill missing values only for numeric columns
X[numeric_columns] = X[numeric_columns].fillna(X[numeric_columns].mean())

# For non-numeric columns, you can fill missing values with a placeholder or use more appropriate strategies
# Example: Filling missing values in non-numeric columns with a placeholder value
X[non_numeric_columns] = X[non_numeric_columns].fillna('Unknown')

# Ensure the features are ready for scaling and model training
print(X.head())
# Out:
#     x1  x2   x3   x4    x5   x6   x7  x8   x9   x10  ...   x12 x13   x14  \
# 0  A11   6  A34  A43  1169  A65  A75   4  A93  A101  ...  A121  67  A143
# 1  A12  48  A32  A43  5951  A61  A73   2  A92  A101  ...  A121  22  A143
# 2  A14  12  A34  A46  2096  A61  A74   2  A93  A101  ...  A121  49  A143
# 3  A11  42  A32  A42  7882  A61  A74   2  A93  A103  ...  A122  45  A143
# 4  A11  24  A33  A40  4870  A61  A73   3  A93  A101  ...  A124  53  A143
#
#     x15 x16   x17 x18   x19   x20 Class
# 0  A152   2  A173   1  A192  A201     1
# 1  A152   1  A173   1  A191  A201     2
# 2  A152   1  A172   2  A191  A201     1
# 3  A153   1  A173   2  A191  A201     1
# 4  A153   2  A173   2  A191  A201     2
#
# [5 rows x 21 columns]

# %%
# Encoding categorical variables using One-Hot Encoding
X_encoded = pd.get_dummies(X, drop_first=True)

# Check the transformed dataset after encoding
print(X_encoded.head())

# Splitting the dataset into training and testing sets
from sklearn.model_selection import train_test_split

# Since we don't have a target column, we will create a synthetic target for this example.
# You can replace 'y' with the actual target if available in your dataset.
y = np.random.randint(0, 2, X.shape[0])  # Random binary target for demonstration (replace this with your actual target)

# Splitting the dataset into training (70%) and testing sets (30%)
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.3, random_state=42)

# Feature scaling for the training and test sets
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Check the shapes of the training and testing sets to ensure the split is correct
print("Training set shape:", X_train.shape)
print("Test set shape:", X_test.shape)
# Out:
#    x2    x5  x8  x11  x13  x16  x18  Class  x1_A12  x1_A13  ...  x12_A124  \
# 0   6  1169   4    4   67    2    1      1   False   False  ...     False
# 1  48  5951   2    2   22    1    1      2    True   False  ...     False
# 2  12  2096   2    3   49    1    2      1   False   False  ...     False
# 3  42  7882   2    4   45    1    2      1   False   False  ...     False
# 4  24  4870   3    4   53    2    2      2   False   False  ...      True
#
#    x14_A142  x14_A143  x15_A152  x15_A153  x17_A172  x17_A173  x17_A174  \
# 0     False      True      True     False     False      True     False
# 1     False      True      True     False     False      True     False
# 2     False      True      True     False      True     False     False
# 3     False      True     False      True     False      True     False
# 4     False      True     False      True     False      True     False
#
#    x19_A192  x20_A202
# 0      True     False
# 1     False     False
# ...

# %%
# Train the Decision Tree classifier
dt_classifier = DecisionTreeClassifier(random_state=42)
dt_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Train the k-NN classifier
knn_classifier = KNeighborsClassifier(n_neighbors=5)  # You can tune the number of neighbors
knn_classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Predicting with Decision Tree
y_pred_dt = dt_classifier.predict(X_test)

# Evaluate the model
accuracy_dt = accuracy_score(y_test, y_pred_dt)
cm_dt = confusion_matrix(y_test, y_pred_dt)
cr_dt = classification_report(y_test, y_pred_dt)

print("Decision Tree Accuracy:", accuracy_dt)
print("Confusion Matrix:\n", cm_dt)
print("Classification Report:\n", cr_dt)
# Out:
# Decision Tree Accuracy: 0.43
# Confusion Matrix:
#  [[60 73]
#  [98 69]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.38      0.45      0.41       133
#            1       0.49      0.41      0.45       167
#
#     accuracy                           0.43       300
#    macro avg       0.43      0.43      0.43       300
# weighted avg       0.44      0.43      0.43       300

# %%
# Predicting with k-NN
y_pred_knn = knn_classifier.predict(X_test)

# Evaluate the model
accuracy_knn = accuracy_score(y_test, y_pred_knn)
cm_knn = confusion_matrix(y_test, y_pred_knn)
cr_knn = classification_report(y_test, y_pred_knn)

print("k-NN Accuracy:", accuracy_knn)
print("Confusion Matrix:\n", cm_knn)
print("Classification Report:\n", cr_knn)
# Out:
# k-NN Accuracy: 0.5033333333333333
# Confusion Matrix:
#  [[71 62]
#  [87 80]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.45      0.53      0.49       133
#            1       0.56      0.48      0.52       167
#
#     accuracy                           0.50       300
#    macro avg       0.51      0.51      0.50       300
# weighted avg       0.51      0.50      0.50       300
